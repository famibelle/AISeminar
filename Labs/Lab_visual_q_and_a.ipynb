# %% [markdown]
# # Lab: Visual Question & Answering
#
# The full lab can be found at https://learn.deeplearning.ai/

# %% [markdown]
# * Load the Model and the Processor.

# %%
from transformers import BlipForQuestionAnswering
# Out:
# 2024-12-03 17:13:13.660058: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733242393.680555  223155 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733242393.686882  223155 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-03 17:13:13.707613: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = BlipForQuestionAnswering.from_pretrained(
    "Salesforce/blip-vqa-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]

# %%
from transformers import AutoProcessor

# %%
processor = AutoProcessor.from_pretrained(
    "Salesforce/blip-vqa-base")
# Out:
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
from PIL import Image
import requests

# %%
url = "https://www.lalux.lu/fileadmin/_processed_/6/f/csm_1600x1024_StaffProtect_2fad8d9f42.jpg"
image = Image.open(requests.get(url, stream=True).raw)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1024>

# %% [markdown]
# - Posez une `question` à propos de l'image.

# %%
question = "how many people are in the picture?"

# %%
inputs = processor(image, question, return_tensors="pt")

# %%
out = model.generate(**inputs)

# %%
print(processor.decode(out[0], skip_special_tokens=True))
# Out:
# 5
